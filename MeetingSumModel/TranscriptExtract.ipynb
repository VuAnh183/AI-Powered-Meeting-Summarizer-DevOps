# %%
import os
import whisper
import torchaudio
import torch
from whisper.audio import log_mel_spectrogram, pad_or_trim

# Check if GPU is available 
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
custom_model_dir = "./models/whisper"

# Load Whisper medium model
model = whisper.load_model("medium", device=device, download_root=custom_model_dir)

# Directory containing the audio files
audio_root = "amicorpus"

# %%
allocated = torch.cuda.memory_allocated() / 1024**2
reserved = torch.cuda.memory_reserved() / 1024**2
print(f"{allocated:.2f} MB allocated, {reserved:.2f} MB reserved")
# Out:
# 2914.90 MB allocated, 4378.00 MB reserved

# %%
def transcribe_audio(audio_path, chunk_duration_sec=30):
    """
    Transcribe long audio using OpenAI Whisper with manual chunking (GPU-accelerated).
    """
    # Load and resample audio
    waveform, sample_rate = torchaudio.load(audio_path)

    # Resample to 16000 Hz
    if sample_rate != 16000:
        resampler = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=16000)
        waveform = resampler(waveform)

    waveform = waveform.squeeze()  # mono
    total_samples = waveform.shape[0]
    chunk_size = int(16000 * chunk_duration_sec)

    transcriptions = []

    for start in range(0, total_samples, chunk_size):
        end = min(start + chunk_size, total_samples)
        chunk = waveform[start:end]

        # Pad or trim to fit model's input expectations
        chunk = pad_or_trim(chunk, length=chunk_size)

        # Convert to log-Mel spectrogram (as Whisper expects)
        mel = log_mel_spectrogram(chunk).to(model.device)

        # Decode
        options = whisper.DecodingOptions(language="en", fp16=True)
        result = whisper.decode(model, mel, options)

        if isinstance(result, list):
            text = " ".join(r.text.strip() for r in result)
        else:
            text = result.text.strip()

        transcriptions.append(text)
        torch.cuda.empty_cache()

    return " ".join(transcriptions)

# %%
# Walk through all audio files
for root, dirs, files in os.walk(audio_root):
    for file in files:
        if file.endswith(".wav"):
            audio_path = os.path.join(root, file)
            txt_path = os.path.splitext(audio_path)[0] + ".txt"

            # Skip if transcript already exists
            if os.path.exists(txt_path):
                print(f"Skipping {audio_path} — transcript already exists.")
                continue

            print(f"Transcribing {audio_path}...")
            try:
                transcript = transcribe_audio(audio_path)
                with open(txt_path, "w", encoding="utf-8") as f:
                    f.write(transcript)
                print(f"Saved transcript to {txt_path}")
            except Exception as e:
                print(f"Failed to process {audio_path}: {e}")
# Out:
# Skipping amicorpus\ES2009a\ES2009a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2009b\ES2009b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2009c\ES2009c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2009d\ES2009d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2010a\ES2010a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2010b\ES2010b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2010c\ES2010c.Mix-Headset.wav — transcript already exists.
# Transcribing amicorpus\ES2010d\ES2010d.Mix-Headset.wav...
# Saved transcript to amicorpus\ES2010d\ES2010d.Mix-Headset.txt
# Skipping amicorpus\ES2011a\ES2011a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2011b\ES2011b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2011c\ES2011c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2011d\ES2011d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2012a\ES2012a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2012b\ES2012b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2012c\ES2012c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2012d\ES2012d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2013a\ES2013a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2013b\ES2013b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2013c\ES2013c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2013d\ES2013d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2014a\ES2014a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2014b\ES2014b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2014c\ES2014c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2014d\ES2014d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2015a\ES2015a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2015b\ES2015b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2015c\ES2015c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2015d\ES2015d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2016a\ES2016a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2016b\ES2016b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2016c\ES2016c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\ES2016d\ES2016d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1000a\IS1000a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1000b\IS1000b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1000c\IS1000c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1000d\IS1000d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1001a\IS1001a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1001b\IS1001b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1001c\IS1001c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1001d\IS1001d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1002b\IS1002b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1002c\IS1002c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1002d\IS1002d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1003a\IS1003a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1003b\IS1003b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1003c\IS1003c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1003d\IS1003d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1004a\IS1004a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1004b\IS1004b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1004c\IS1004c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1004d\IS1004d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1005a\IS1005a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1005b\IS1005b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1005c\IS1005c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1006a\IS1006a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1006b\IS1006b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1006c\IS1006c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1006d\IS1006d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1007a\IS1007a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1007b\IS1007b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1007c\IS1007c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1007d\IS1007d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1008a\IS1008a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1008b\IS1008b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1008c\IS1008c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1008d\IS1008d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1009a\IS1009a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1009b\IS1009b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1009c\IS1009c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\IS1009d\IS1009d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3003a\TS3003a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3003b\TS3003b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3003c\TS3003c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3003d\TS3003d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3004a\TS3004a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3004b\TS3004b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3004c\TS3004c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3004d\TS3004d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3005a\TS3005a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3005b\TS3005b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3005c\TS3005c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3005d\TS3005d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3006a\TS3006a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3006b\TS3006b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3006c\TS3006c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3006d\TS3006d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3007a\TS3007a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3007b\TS3007b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3007c\TS3007c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3007d\TS3007d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3008a\TS3008a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3008b\TS3008b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3008c\TS3008c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3008d\TS3008d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3009a\TS3009a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3009b\TS3009b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3009c\TS3009c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3009d\TS3009d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3010a\TS3010a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3010b\TS3010b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3010c\TS3010c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3010d\TS3010d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3011a\TS3011a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3011b\TS3011b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3011c\TS3011c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3011d\TS3011d.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3012a\TS3012a.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3012b\TS3012b.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3012c\TS3012c.Mix-Headset.wav — transcript already exists.
# Skipping amicorpus\TS3012d\TS3012d.Mix-Headset.wav — transcript already exists.
